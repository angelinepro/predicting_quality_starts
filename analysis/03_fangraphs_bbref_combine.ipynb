# %% [markdown]
# # Notebook 3: Combining Fangraphs and Baseball Reference Data

# %% [markdown]
# ### Introduction

# %% [markdown]
# From the previous two notebooks, we now have clean projection and season data to use for modeling. In this notebook, I'll combine the relevant datasets to form the training, validation, and test set.

# %%
import pandas as pd

# %% [markdown]
# ### Data for Training Model
#
# My training set will use season data from 2016 and projection data from 2017 to predict quality starts in 2017. This code goes over how I combine them all, and what rows/players were dropped.
#
#  Need to have:
# - season QS data for 2017
# - projection (all) data for 2017
# - season (all) data for 2016

# %%
qs_17 = pd.read_csv('../data/season_2017_c.csv')
qs_17_simple = qs_17[['Full_Name', 'ID', 'QS_2017']]

# %%
season_2016 = pd.read_csv('../data/season_2016_c.csv')

# %% [markdown]
# This dataset (s16_qs17) has a QS_2017 value for all rows. However, not all rows will have 2016 season data. This is all taken from baseball reference.

# %%
s16_qs17 = season_2016.merge(qs_17_simple, left_on =['ID', 'Full_Name'], 
                                    right_on = ['ID', 'Full_Name'], how = 'right')
# Performing a right join here means that all rows have a QS_2017 value, and not all rows have 2016 season data.

# %%
s16_qs17.shape
# Out:
# (316, 38)

# %% [markdown]
# Now we will read in the projection data and perform the first match, on player ID. Note that player ID has been constructed in the Fangraphs projection data based on the Player Name. It will not necessarily match the ID given by Baseball Reference, and will need to be updated for non-matches.

# %%
proj17 = pd.read_csv('../data/projected_2017_c.csv')

# %%
train_matchID = s16_qs17.merge(proj17, left_on =['ID'], 
                                    right_on = ['ID'], how = 'inner')

# %% [markdown]
# This dataset is the result of the first match between the 2017QS/2016 season data and the 2017 projection data.

# %%
train_matchID
# Out:
#             Full_Name         ID  Age_2016 Tm_2016  IP_2016  G_2016  GS_2016  \
# 0         Tim Adleman  adlemti01      28.0     CIN     69.2    13.0     13.0
# 1      Raul Alcantara  alcanra01      23.0     OAK     22.1     5.0      5.0
# 2      Chase Anderson  anderch01      28.0     MIL    151.2    31.0     30.0
# 3      Tyler Anderson  anderty01      26.0     COL    114.1    19.0     19.0
# 4       Matt Andriese  andrima01      26.0     TBR    127.2    29.0     19.0
# ..                ...        ...       ...     ...      ...     ...      ...
# 259         Adam Wilk   wilkad01       NaN     NaN      NaN     NaN      NaN
# 260         Adam Wilk   wilkad01       NaN     NaN      NaN     NaN      NaN
# 261   Aaron Wilkerson  wilkeaa01       NaN     NaN      NaN     NaN      NaN
# 262       Travis Wood   woodtr01       NaN     NaN      NaN     NaN      NaN
# 263  Brandon Woodruff  woodrbr01       NaN     NaN      NaN     NaN      NaN
#
#      Wgs_2016  Lgs_2016  ND_2016  ...  BABIP_2017  ERA_2017  FIP_2017  \
# 0         4.0       4.0      5.0  ...       0.285      4.76      4.97
# 1         1.0       3.0      1.0  ...       0.296      5.10      5.00
# 2         9.0      11.0     10.0  ...       0.293      4.64      4.69
# 3         5.0       6.0      8.0  ...       0.302      4.28      4.47
# 4         7.0       7.0      5.0  ...       0.293      3.71      3.49
# ..        ...       ...      ...  ...         ...       ...       ...
# 259       NaN       NaN      NaN  ...       0.296      4.78      4.62
# 260       NaN       NaN      NaN  ...       0.291      5.10      4.93
# 261       NaN       NaN      NaN  ...       0.297      4.43      4.32
# 262       NaN       NaN      NaN  ...       0.271      3.39      3.91
# 263       NaN       NaN      NaN  ...       0.296      4.27      4.15
#
#      ERA-_2017  FIP-_2017  K/9_2017  BB/9_2017  HR/9_2017  ERA+_2017  \
# 0          113        116      6.61       2.98       1.45         84
# 1          126        121      5.42       2.28       1.49         78
# 2          108        108      7.28       2.96       1.42         88
# 3           87         99      7.05       3.09       1.19        110
# 4           91         86      7.93       1.89       1.01        106
# ..         ...        ...       ...        ...        ...        ...
# 259        117        113      6.29       2.47       1.35         83
# 260        129        118      6.29       2.47       1.51         74
# 261        103        100      8.52       3.18       1.25         92
# 262         82         94      8.56       3.54       1.03        116
# 263         99         96      8.00       3.05       1.09         95
#
#      zWAR_2017
# 0          0.4
# 1          0.0
# 2          1.1
# 3          2.3
# 4          2.3
# ..         ...
# 259        0.3
# 260       -0.5
# 261        1.3
# 262        0.5
# 263        1.6
#
# [264 rows x 64 columns]

# %% [markdown]
# Let's capture the rest of the unmatched data, where there was no ID that lined up.

# %%
train_matchID_unmatched_bbref = s16_qs17[~s16_qs17.ID.isin(train_matchID.ID)]
train_matchID_unmatched_proj  = proj17[~proj17.ID.isin(train_matchID.ID)].drop(['ID'], axis = 1)

# %% [markdown]
# Now let's perform the second match, on Full_Name.

# %%
train_match_Full_Name = train_matchID_unmatched_bbref.merge(train_matchID_unmatched_proj, left_on =['Full_Name'], 
                                    right_on = ['Player'], how = 'inner')

# %%
train_match_Full_Name
# Out:
#             Full_Name         ID  Age_2016 Tm_2016  IP_2016  G_2016  GS_2016  \
# 0      Brett Anderson  anderbr04      28.0     LAD     11.1     4.0      3.0
# 1        Homer Bailey  baileho02      30.0     CIN     23.0     6.0      6.0
# 2        Wei-Yin Chen   chenwe02      30.0     MIA    123.1    22.0     22.0
# 3         Zach Davies  davieza02      23.0     MIL    163.1    28.0     28.0
# 4         R.A. Dickey  dicker.01      41.0     TOR    169.2    30.0     29.0
# 5        Jaime Garcia  garcija02      29.0     STL    171.2    32.0     30.0
# 6        Jaime Garcia  garcija02      29.0     STL    171.2    32.0     30.0
# 7     Miguel Gonzalez  gonzami03      32.0     CHW    135.0    24.0     23.0
# 8            Jon Gray   grayjo02      24.0     COL    168.0    29.0     29.0
# 9          Chad Green  greench03      25.0     NYY     45.2    12.0      8.0
# 10      Junior Guerra  guerrju02      31.0     MIL    121.2    20.0     20.0
# 11    Felix Hernandez  hernafe02      30.0     SEA    153.1    25.0     25.0
# 12       Jeff Hoffman  hoffmje02      23.0     COL     31.1     8.0      6.0
# 13    Carlos Martinez  martica04      24.0     STL    195.1    31.0     31.0
# 14         Matt Moore  moorema02      27.0     TOT    198.1    33.0     33.0
# 15     Charlie Morton  mortoch02      32.0     PHI     17.1     4.0      4.0
# 16       Jimmy Nelson  nelsoji02      27.0     MIL    179.1    32.0     32.0
# 17       Luis Perdomo  perdolu02      23.0     SDP    146.2    35.0     20.0
# 18       Martin Perez  perezma02      25.0     TEX    198.2    33.0     33.0
# 19     Erasmo Ramirez  ramirer02      26.0     TBR     90.2    64.0      1.0
# 20         Robbie Ray    rayro02      24.0     ARI    174.1    32.0     32.0
# 21  Eduardo Rodriguez  rodried05      23.0     BOS    107.0    20.0     20.0
# 22        CC Sabathia  sabatc.01      35.0     NYY    179.2    30.0     30.0
# 23      James Shields  shielja02      34.0     TOT    181.2    33.0     33.0
# 24      Jake Thompson  thompja03      22.0     PHI     53.2    10.0     10.0
# 25       Jered Weaver  weaveje02      33.0     LAA    178.0    31.0     31.0
# 26          Alex Wood   woodal02      25.0     LAD     60.1    14.0     10.0
# 27      Daniel Wright  wrighda04      25.0     TOT     39.2     9.0      7.0
# 28  Jordan Zimmermann  zimmejo02      30.0     DET    105.1    19.0     18.0
# 29          Chad Bell   bellch02       NaN     NaN      NaN     NaN      NaN
# 30      Luis Castillo  castilu02       NaN     NaN      NaN     NaN      NaN
# 31      Luis Castillo  castilu02       NaN     NaN      NaN     NaN      NaN
# 32       Rookie Davis  davisro03       NaN     NaN      NaN     NaN      NaN
# 33      Chase De Jong  dejonch01       NaN     NaN      NaN     NaN      NaN
# 34     Marco Gonzales  gonzama02       NaN     NaN      NaN     NaN      NaN
# 35         Matt Grace  gracema02       NaN     NaN      NaN     NaN      NaN
# 36      Brian Johnson  johnsbr02       NaN     NaN      NaN     NaN      NaN
# 37       Deck McGuire  mcguide02       NaN     NaN      NaN     NaN      NaN
# 38       Andrew Moore  moorean02       NaN     NaN      NaN     NaN      NaN
# 39        Chris Smith  smithch08       NaN     NaN      NaN     NaN      NaN
# 40        Chris Smith  smithch08       NaN     NaN      NaN     NaN      NaN
#
#     Wgs_2016  Lgs_2016  ND_2016  ...  BABIP_2017  ERA_2017  FIP_2017  \
# 0        0.0       2.0      1.0  ...       0.291      4.44      4.29
# 1        2.0       3.0      1.0  ...       0.297      4.50      4.28
# 2        5.0       5.0     12.0  ...       0.283      3.73      3.97
# 3       11.0       7.0     10.0  ...       0.292      3.99      3.95
# 4       10.0      14.0      5.0  ...       0.273      4.50      4.71
# 5       10.0      13.0      7.0  ...       0.292      4.03      4.11
# 6       10.0      13.0      7.0  ...       0.292      4.03      4.11
# 7        5.0       8.0     10.0  ...       0.297      4.63      4.63
# 8       10.0      10.0      9.0  ...       0.309      4.18      4.06
# 9        2.0       4.0      2.0  ...       0.303      4.69      4.47
# 10       9.0       3.0      8.0  ...       0.279      4.24      4.54
# 11      11.0       8.0      6.0  ...       0.285      3.66      3.78
# 12       0.0       4.0      2.0  ...       0.305      4.49      4.74
# 13      16.0       9.0      6.0  ...       0.289      3.33      3.63
# 14      13.0      12.0      8.0  ...       0.286      3.82      3.98
# 15       1.0       1.0      2.0  ...       0.303      4.59      4.42
# 16       8.0      16.0      8.0  ...       0.297      4.34      4.45
# 17       8.0       9.0      3.0  ...       0.312      5.09      4.63
# 18      10.0      11.0     12.0  ...       0.295      4.48      4.35
# 19       1.0       0.0      0.0  ...       0.281      4.08      4.43
# 20       8.0      15.0      9.0  ...       0.319      3.73      3.50
# 21       3.0       7.0     10.0  ...       0.295      4.11      4.09
# 22       9.0      12.0      9.0  ...       0.299      4.57      4.42
# 23       6.0      19.0      8.0  ...       0.299      4.88      4.81
# 24       3.0       6.0      1.0  ...       0.289      4.82      4.97
# 25      12.0      12.0      7.0  ...       0.283      4.59      4.64
# 26       1.0       4.0      5.0  ...       0.288      4.09      4.03
# 27       1.0       4.0      2.0  ...       0.296      4.60      4.39
# 28       9.0       7.0      2.0  ...       0.298      4.14      4.07
# 29       NaN       NaN      NaN  ...       0.303      5.14      4.86
# 30       NaN       NaN      NaN  ...       0.288      4.59      4.61
# 31       NaN       NaN      NaN  ...       0.286      4.65      4.82
# 32       NaN       NaN      NaN  ...       0.293      5.25      5.25
# 33       NaN       NaN      NaN  ...       0.287      4.62      4.65
# 34       NaN       NaN      NaN  ...       0.296      4.81      4.73
# 35       NaN       NaN      NaN  ...       0.294      3.84      3.83
# 36       NaN       NaN      NaN  ...       0.302      4.68      4.75
# 37       NaN       NaN      NaN  ...       0.289      5.29      5.14
# 38       NaN       NaN      NaN  ...       0.298      4.82      4.55
# 39       NaN       NaN      NaN  ...       0.290      4.62      4.50
# 40       NaN       NaN      NaN  ...       0.301      4.53      4.24
#
#     ERA-_2017  FIP-_2017  K/9_2017  BB/9_2017  HR/9_2017  ERA+_2017  zWAR_2017
# 0         112        105      6.04       2.39       1.14         85        0.4
# 1         107        100      7.67       2.76       1.23         89        0.6
# 2          91         98      7.16       1.90       1.16        106        2.4
# 3          93         91      7.76       2.55       1.06        102        2.6
# 4         109        116      6.19       3.21       1.17         88        1.1
# 5          98        102      7.99       2.62       1.20         98        1.6
# 6          98        102      7.99       2.62       1.20         98        1.6
# 7         109        107      6.95       2.78       1.39         89        1.2
# 8          85         90      8.83       3.08       1.16        112        3.2
# 9         110        102      8.25       2.87       1.47         87        0.8
# 10         99        105      8.20       3.66       1.32         96        1.5
# 11         91         92      8.58       2.76       1.05        104        3.0
# 12         91        105      7.69       3.54       1.36        105        2.3
# 13         81         88      8.53       3.05       0.84        119        4.2
# 14         96        100      8.35       3.67       0.94         98        1.5
# 15        111        106      7.47       3.20       1.17         88        0.6
# 16        101        103      7.57       3.39       1.11         94        1.9
# 17        127        112      6.65       2.98       1.29         73       -0.6
# 18        102        102      5.36       3.05       0.95         94        1.4
# 19        100        109      5.44       2.62       1.15         97        0.1
# 20         85         83     10.98       3.47       1.07        112        3.4
# 21         93         98      7.67       2.76       1.17        103        2.2
# 22        108        101      7.48       2.90       1.31         89        1.0
# 23        115        111      7.64       3.31       1.52         85        1.0
# 24        117        117      6.69       3.31       1.39         81        0.4
# 25        115        114      5.79       2.52       1.32         84        0.5
# 26        103         99      7.59       2.70       1.09         93        1.1
# 27        115        108      6.32       2.30       1.21         84        0.4
# 28         97         96      6.72       1.95       1.19        100        2.1
# 29        121        114      6.61       4.22       1.19         81        0.2
# 30        112        114      6.19       2.91       1.15         86        0.6
# 31        110        112      6.81       2.96       1.36         86        0.5
# 32        125        122      6.28       2.99       1.61         76       -0.3
# 33        117        114      7.89       2.99       1.43         82        0.3
# 34        118        115      6.67       3.17       1.31         82        0.3
# 35         92         93      6.34       2.80       0.74        105        0.3
# 36        106        114      7.26       4.13       1.19         90        0.8
# 37        129        124      6.70       3.38       1.55         75       -0.4
# 38        119        110      6.39       2.11       1.39         79        0.2
# 39        114        109      7.55       3.55       1.24         86        0.6
# 40        106        100      9.39       3.35       1.34         91       -0.1
#
# [41 rows x 64 columns]

# %%
train_matchID_unmatched_bbref_r2 = s16_qs17[~s16_qs17.ID.isin(train_matchID.ID) & ~s16_qs17.ID.isin(train_match_Full_Name.ID)]
train_matchID_unmatched_proj_r2  = proj17[~proj17.ID.isin(train_matchID.ID) & ~proj17.ID.isin(train_match_Full_Name.ID)]

# %%
#Can confirm, none of these players appeared in the 2017 projection data.
train_matchID_unmatched_bbref_r2
# Out:
#                Full_Name         ID  Age_2016 Tm_2016  IP_2016  G_2016  \
# 1          Andrew Albers  alberan01      30.0     MIN     17.0     6.0
# 29        Jhoulys Chacin  chacijh01      28.0     TOT    144.0    34.0
# 38        Patrick Corbin  corbipa01      26.0     ARI    155.2    36.0
# 57       Yovani Gallardo  gallayo01      30.0     BAL    118.0    23.0
# 117  Lance McCullers Jr.  mcculla02      22.0     HOU     81.0    14.0
# 183          Dan Straily  straida01      27.0     CIN    191.1    34.0
# 197         Jacob Turner  turneja01      25.0     CHW     24.2    18.0
# 219          Chris Young  youngch03      37.0     KCR     88.2    34.0
# 223       Bronson Arroyo  arroybr01       NaN     NaN      NaN     NaN
# 242           Dayan Diaz   diazda01       NaN     NaN      NaN     NaN
# 243          Miguel Diaz   diazmi02       NaN     NaN      NaN     NaN
# 249        Jack Flaherty  flaheja01       NaN     NaN      NaN     NaN
# 257          Luiz Gohara  goharlu01       NaN     NaN      NaN     NaN
# 261       Jeremy Guthrie  guthrje01       NaN     NaN      NaN     NaN
# 272             Zach Lee    leeza01       NaN     NaN      NaN     NaN
# 273      Mark Leiter Jr.  leitema02       NaN     NaN      NaN     NaN
# 293         Chris Rowley  rowlech01       NaN     NaN      NaN     NaN
# 299          Caleb Smith  smithca03       NaN     NaN      NaN     NaN
# 307     Hector Velazquez  velazhe01       NaN     NaN      NaN     NaN
# 313  Asher Wojciechowski  wojcias01       NaN     NaN      NaN     NaN
#
#      GS_2016  Wgs_2016  Lgs_2016  ND_2016  ...  RS/GS_2016  RS/IP_2016  \
# 1        2.0       0.0       0.0      2.0  ...         6.4        14.1
# 29      22.0       5.0       8.0      9.0  ...         4.6         3.5
# 38      24.0       4.0      12.0      8.0  ...         4.7         4.4
# 57      23.0       6.0       8.0      9.0  ...         4.6         4.5
# 117     14.0       6.0       5.0      3.0  ...         3.2         3.3
# 183     31.0      14.0       8.0      9.0  ...         5.3         4.3
# 197      2.0       0.0       1.0      1.0  ...         3.0         2.3
# 219     13.0       1.0       8.0      4.0  ...         2.9         2.5
# 223      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 242      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 243      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 249      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 257      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 261      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 272      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 273      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 293      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 299      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 307      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 313      NaN       NaN       NaN      NaN  ...         NaN         NaN
#
#      IP/GS_2016  Pit/GS_2016  <80_2016  80-99_2016  100-119_2016  ≥120_2016  \
# 1           3.3         73.0       1.0         1.0           0.0        0.0
# 29          5.2         87.0       4.0        17.0           1.0        0.0
# 38          5.5         91.0       3.0        17.0           4.0        0.0
# 57          5.1         92.0       2.0        15.0           6.0        0.0
# 117         5.8         96.0       1.0         9.0           4.0        0.0
# 183         5.9         94.0       4.0        18.0           9.0        0.0
# 197         3.7         91.0       0.0         1.0           1.0        0.0
# 219         4.3         82.0       4.0         8.0           1.0        0.0
# 223         NaN          NaN       NaN         NaN           NaN        NaN
# 242         NaN          NaN       NaN         NaN           NaN        NaN
# 243         NaN          NaN       NaN         NaN           NaN        NaN
# 249         NaN          NaN       NaN         NaN           NaN        NaN
# 257         NaN          NaN       NaN         NaN           NaN        NaN
# 261         NaN          NaN       NaN         NaN           NaN        NaN
# 272         NaN          NaN       NaN         NaN           NaN        NaN
# 273         NaN          NaN       NaN         NaN           NaN        NaN
# 293         NaN          NaN       NaN         NaN           NaN        NaN
# 299         NaN          NaN       NaN         NaN           NaN        NaN
# 307         NaN          NaN       NaN         NaN           NaN        NaN
# 313         NaN          NaN       NaN         NaN           NaN        NaN
#
#      Max_2016  QS_2017
# 1        88.0        2
# 29      114.0       16
# 38      108.0       19
# 57      108.0        5
# 117     117.0        9
# 183     112.0       12
# 197     101.0        1
# 219     101.0        0
# 223       NaN        3
# 242       NaN        0
# 243       NaN        0
# 249       NaN        0
# 257       NaN        2
# 261       NaN        0
# 272       NaN        0
# 273       NaN        4
# 293       NaN        0
# 299       NaN        0
# 307       NaN        0
# 313       NaN        1
#
# [20 rows x 38 columns]

# %% [markdown]
# Now that I've found all possible player matches, I'll finalize the training data, and output it as a csv.

# %%
training_data_model = pd.concat([train_matchID, train_match_Full_Name], ignore_index = True, axis = 0)
#training_data_model.to_csv('training_data_model.csv', index = False)

# %% [markdown]
# ### Data for Validation Model
#
# My validation set will use season data from 2017 and projection data from 2018 to predict quality starts in 2018. This code goes over how I combine them all, and what rows/players were dropped. This is similar to what I did for the training data, but for a different year.
#
#  Need to have:
# - season QS data for 2018
# - projection (all) data for 2018
# - season (all) data for 2017

# %%
qs_18 = pd.read_csv('../data/season_2018_c.csv')
qs_18_simple = qs_18[['Full_Name', 'ID', 'QS_2018']]

# %%
season_2017 = pd.read_csv('../data/season_2017_c.csv')
s17_qs18 = season_2017.merge(qs_18_simple, left_on =['ID', 'Full_Name'], 
                                    right_on = ['ID', 'Full_Name'], how = 'right')

# %%
proj18 = pd.read_csv('../data/projected_2018_c.csv')

# %%
train_matchID = s17_qs18.merge(proj18, left_on =['ID'], 
                                    right_on = ['ID'], how = 'inner')

# %%
train_matchID_unmatched_bbref = s17_qs18[~s17_qs18.ID.isin(train_matchID.ID)]
train_matchID_unmatched_proj  = proj18[~proj18.ID.isin(train_matchID.ID)].drop(['ID'], axis = 1)

# %%
train_match_Full_Name = train_matchID_unmatched_bbref.merge(train_matchID_unmatched_proj, left_on =['Full_Name'], 
                                    right_on = ['Player'], how = 'inner')

# %%
train_matchID_unmatched_bbref_r2 = s17_qs18[~s17_qs18.ID.isin(train_matchID.ID) & ~s17_qs18.ID.isin(train_match_Full_Name.ID)]
train_matchID_unmatched_proj_r2  = proj18[~proj18.ID.isin(train_matchID.ID) & ~proj18.ID.isin(train_match_Full_Name.ID)]

# %%
train_matchID_unmatched_bbref_r2
# Out:
#                Full_Name         ID  Age_2017 Tm_2017  IP_2017  G_2017  \
# 119  Lance McCullers Jr.  mcculla02      23.0     HOU    118.2    22.0
# 130           Matt Moore  moorema02      28.0     SFG    174.1    32.0
# 132         Joe Musgrove  musgrjo01      24.0     HOU    109.1    38.0
# 196         Jacob Turner  turneja01      26.0     WSN     39.0    18.0
# 218      Scott Alexander  alexasc02       NaN     NaN      NaN     NaN
# 229         Jeff Brigham  brighje01       NaN     NaN      NaN     NaN
# 238  Enyel De Los Santos  delosen01       NaN     NaN      NaN     NaN
# 245       Caleb Ferguson  ferguca01       NaN     NaN      NaN     NaN
# 246           Matt Festa  festama01       NaN     NaN      NaN     NaN
# 251          Drew Gagnon  gagnodr01       NaN     NaN      NaN     NaN
# 265       Drew Hutchison  hutchdr01       NaN     NaN      NaN     NaN
# 266           Josh James  jamesjo02       NaN     NaN      NaN     NaN
# 281    Jonathan Loaisiga  loaisjo01       NaN     NaN      NaN     NaN
# 306        Evan Phillips  phillev01       NaN     NaN      NaN     NaN
# 320       Adrian Sampson  sampsad01       NaN     NaN      NaN     NaN
# 326      Jeffrey Springs  sprinje01       NaN     NaN      NaN     NaN
# 340         Bryse Wilson  wilsobr02       NaN     NaN      NaN     NaN
#
#      GS_2017  Wgs_2017  Lgs_2017  ND_2017  ...  RS/GS_2017  RS/IP_2017  \
# 119     22.0       7.0       4.0     11.0  ...         4.9         3.7
# 130     31.0       6.0      15.0     10.0  ...         3.7         3.3
# 132     15.0       4.0       8.0      3.0  ...         4.2         4.0
# 196      2.0       0.0       1.0      1.0  ...         2.5         3.0
# 218      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 229      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 238      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 245      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 246      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 251      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 265      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 266      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 281      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 306      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 320      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 326      NaN       NaN       NaN      NaN  ...         NaN         NaN
# 340      NaN       NaN       NaN      NaN  ...         NaN         NaN
#
#      IP/GS_2017  Pit/GS_2017  <80_2017  80-99_2017  100-119_2017  ≥120_2017  \
# 119         5.4         92.0       3.0        15.0           4.0        0.0
# 130         5.6         92.0       5.0        18.0           7.0        1.0
# 132         5.2         88.0       2.0        11.0           2.0        0.0
# 196         5.7         87.0       0.0         2.0           0.0        0.0
# 218         NaN          NaN       NaN         NaN           NaN        NaN
# 229         NaN          NaN       NaN         NaN           NaN        NaN
# 238         NaN          NaN       NaN         NaN           NaN        NaN
# 245         NaN          NaN       NaN         NaN           NaN        NaN
# 246         NaN          NaN       NaN         NaN           NaN        NaN
# 251         NaN          NaN       NaN         NaN           NaN        NaN
# 265         NaN          NaN       NaN         NaN           NaN        NaN
# 266         NaN          NaN       NaN         NaN           NaN        NaN
# 281         NaN          NaN       NaN         NaN           NaN        NaN
# 306         NaN          NaN       NaN         NaN           NaN        NaN
# 320         NaN          NaN       NaN         NaN           NaN        NaN
# 326         NaN          NaN       NaN         NaN           NaN        NaN
# 340         NaN          NaN       NaN         NaN           NaN        NaN
#
#      Max_2017  QS_2018
# 119     105.0       13
# 130     120.0        2
# 132     102.0       10
# 196      89.0        0
# 218       NaN        0
# 229       NaN        0
# 238       NaN        1
# 245       NaN        0
# 246       NaN        0
# 251       NaN        0
# 265       NaN        0
# 266       NaN        0
# 281       NaN        0
# 306       NaN        0
# 320       NaN        1
# 326       NaN        0
# 340       NaN        0
#
# [17 rows x 38 columns]

# %%
validation_data_model = pd.concat([train_matchID, train_match_Full_Name], ignore_index = True, axis = 0)
#validation_data_model.to_csv('validation_data_model.csv', index = False)

# %% [markdown]
# ### Data for Test Model
#
# My test set will use season data from 2018 and projection data from 2019 to predict quality starts in 2019. This code goes over how I combine them all, and what rows/players were dropped. This is similar to what I did for the training and validation data, but for a different year.
# Need to have:
#
# - season QS data for 2019
# - projection (all) data for 2019
# - season (all) data for 2018

# %%
qs_19 = pd.read_csv('../data/season_2019_c.csv')
qs_19_simple = qs_19[['Full_Name', 'ID', 'QS_2019']]

# %%
season_2018 = pd.read_csv('../data/season_2018_c.csv')

# %%
s18_qs19 = season_2018.merge(qs_19_simple, left_on =['ID', 'Full_Name'], 
                                    right_on = ['ID', 'Full_Name'], how = 'right')

# %%
proj19 = pd.read_csv('../data/projected_2019_c.csv')

# %%
train_matchID = s18_qs19.merge(proj19, left_on =['ID'], 
                                    right_on = ['ID'], how = 'inner')

# %%
train_matchID_unmatched_bbref = s18_qs19[~s18_qs19.ID.isin(train_matchID.ID)]
train_matchID_unmatched_proj  = proj19[~proj19.ID.isin(train_matchID.ID)].drop(['ID'], axis = 1)

# %%
train_match_Full_Name = train_matchID_unmatched_bbref.merge(train_matchID_unmatched_proj, left_on =['Full_Name'], 
                                    right_on = ['Player'], how = 'inner')

# %%
train_matchID_unmatched_bbref_r2 = s18_qs19[~s18_qs19.ID.isin(train_matchID.ID) & ~s18_qs19.ID.isin(train_match_Full_Name.ID)]
train_matchID_unmatched_proj_r2  = proj19[~proj19.ID.isin(train_matchID.ID) & ~proj19.ID.isin(train_match_Full_Name.ID)]

# %%
train_matchID_unmatched_bbref_r2
# Out:
#             Full_Name         ID  Age_2018 Tm_2018  IP_2018  G_2018  GS_2018  \
# 7        Homer Bailey  baileho02      32.0     CIN    106.1    20.0     20.0
# 99      Brian Johnson  johnsbr02      27.0     BOS     99.1    38.0     13.0
# 233      Austin Adams  adamsau02       NaN     NaN      NaN     NaN      NaN
# 252    Ronald Bolanos  bolanro01       NaN     NaN      NaN     NaN      NaN
# 261     Matt Carasiti  carasma01       NaN     NaN      NaN     NaN      NaN
# 266    Emmanuel Clase  claseem01       NaN     NaN      NaN     NaN      NaN
# 270      Randy Dobnak  dobnara01       NaN     NaN      NaN     NaN      NaN
# 275   Montana DuRapau  durapmo01       NaN     NaN      NaN     NaN      NaN
# 276      Tom Eshelman  eshelto01       NaN     NaN      NaN     NaN      NaN
# 277   Ryan Feierabend  feierry01       NaN     NaN      NaN     NaN      NaN
# 293     Dakota Hudson  hudsoda02       NaN     NaN      NaN     NaN      NaN
# 305  Nick Margevicius  margeni01       NaN     NaN      NaN     NaN      NaN
# 310    Reggie McClain  mcclare01       NaN     NaN      NaN     NaN      NaN
# 312     Brendan McKay  mckaybr01       NaN     NaN      NaN     NaN      NaN
# 318    Adrian Morejon  morejad01       NaN     NaN      NaN     NaN      NaN
# 324      Pedro Payano  payanpe01       NaN     NaN      NaN     NaN      NaN
# 325      David Phelps  phelpda01       NaN     NaN      NaN     NaN      NaN
# 327       Zach Plesac  plesaza01       NaN     NaN      NaN     NaN      NaN
# 334    Jose Rodriguez  rodrijo07       NaN     NaN      NaN     NaN      NaN
# 345        Josh Smith  smithjo07       NaN     NaN      NaN     NaN      NaN
# 359      Jose Urquidy  urquijo01       NaN     NaN      NaN     NaN      NaN
# 363        Ryan Weber  weberry01       NaN     NaN      NaN     NaN      NaN
#
#      Wgs_2018  Lgs_2018  ND_2018  ...  RS/GS_2018  RS/IP_2018  IP/GS_2018  \
# 7         1.0      14.0      5.0  ...         2.8         1.6         5.3
# 99        4.0       3.0      6.0  ...         6.8         7.3         4.7
# 233       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 252       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 261       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 266       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 270       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 275       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 276       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 277       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 293       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 305       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 310       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 312       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 318       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 324       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 325       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 327       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 334       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 345       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 359       NaN       NaN      NaN  ...         NaN         NaN         NaN
# 363       NaN       NaN      NaN  ...         NaN         NaN         NaN
#
#      Pit/GS_2018  <80_2018  80-99_2018  100-119_2018  ≥120_2018  Max_2018  \
# 7           89.0       2.0        14.0           4.0        0.0     115.0
# 99          78.0       6.0         6.0           1.0        0.0     104.0
# 233          NaN       NaN         NaN           NaN        NaN       NaN
# 252          NaN       NaN         NaN           NaN        NaN       NaN
# 261          NaN       NaN         NaN           NaN        NaN       NaN
# 266          NaN       NaN         NaN           NaN        NaN       NaN
# 270          NaN       NaN         NaN           NaN        NaN       NaN
# 275          NaN       NaN         NaN           NaN        NaN       NaN
# 276          NaN       NaN         NaN           NaN        NaN       NaN
# 277          NaN       NaN         NaN           NaN        NaN       NaN
# 293          NaN       NaN         NaN           NaN        NaN       NaN
# 305          NaN       NaN         NaN           NaN        NaN       NaN
# 310          NaN       NaN         NaN           NaN        NaN       NaN
# 312          NaN       NaN         NaN           NaN        NaN       NaN
# 318          NaN       NaN         NaN           NaN        NaN       NaN
# 324          NaN       NaN         NaN           NaN        NaN       NaN
# 325          NaN       NaN         NaN           NaN        NaN       NaN
# 327          NaN       NaN         NaN           NaN        NaN       NaN
# 334          NaN       NaN         NaN           NaN        NaN       NaN
# 345          NaN       NaN         NaN           NaN        NaN       NaN
# 359          NaN       NaN         NaN           NaN        NaN       NaN
# 363          NaN       NaN         NaN           NaN        NaN       NaN
#
#      QS_2019
# 7         13
# 99         0
# 233        0
# 252        1
# 261        0
# 266        0
# 270        1
# 275        0
# 276        0
# 277        0
# 293       17
# 305        1
# 310        0
# 312        1
# 318        0
# 324        0
# 325        0
# 327        8
# 334        0
# 345        0
# 359        3
# 363        1
#
# [22 rows x 38 columns]

# %%
test_data_model = pd.concat([train_matchID, train_match_Full_Name], ignore_index = True, axis = 0)
#test_data_model.to_csv('test_data_model.csv', index = False)

# %%
test_data_model.shape
# Out:
# (359, 62)
